# %%
import torch
from utils.positional_embedding import PositionalEmbedding
#device = 'cuda' if torch.cuda.is_available() else 'cpu'
device='cpu'
posEmb = PositionalEmbedding(50,128,device)
# Out:
# C:\Users\shubh\Desktop\NLP_Major\utils\positional_embedding.py:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   angle_arg = torch.tensor(pos / div_term, dtype=torch.float, device=self.device)

# %%
import torch
import matplotlib.pyplot as plt

# Example: Create a sample torch.Tensor

# Plot the heatmap
plt.figure(figsize=(20, 6))
plt.imshow(posEmb.pe[0].numpy(), cmap='viridis', interpolation='nearest')  # Convert to NumPy array
plt.colorbar()  # Add a colorbar to show the value scale
plt.title("Heatmap of torch.Tensor")
plt.show()
